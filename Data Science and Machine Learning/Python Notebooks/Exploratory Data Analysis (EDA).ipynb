# %%
import pandas as pd
from scipy import stats
df = pd.read_csv("data/iris.csv")
#df = df.loc[:, df.columns!="variety"]
#df
#df = df.skiprows=[0]
med =  df.iloc[1:, 0:4].median()
print(f"median {med}")
mean =  df.iloc[1:, 0:4].median()
print(f"median {mean}")
# Out:
# median sepal.length    5.8
# sepal.width     3.0
# petal.length    4.4
# petal.width     1.3
# dtype: float64
# median sepal.length    5.8
# sepal.width     3.0
# petal.length    4.4
# petal.width     1.3
# dtype: float64

# %%
print(df.describe())
# Out:
#               sepal.length  sepal.width  petal.length
# sepal.length      1.000000    -0.112106      0.871281
# sepal.width      -0.112106     1.000000     -0.423302
# petal.length      0.871281    -0.423302      1.000000

# %%
print(df.iloc[1:, 0:4].corr())
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.112106      0.871281     0.816961
# sepal.width      -0.112106     1.000000     -0.423302    -0.360480
# petal.length      0.871281    -0.423302      1.000000     0.962423
# petal.width       0.816961    -0.360480      0.962423     1.000000

# %%
mean = df.select_dtypes(include=[float, int]).mean()
median = df.select_dtypes(include=[float, int]).median()
print(mean)
print(median)
correleation_coefficients = df.select_dtypes(include=[float, int]).corr()
print(correleation_coefficients)
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64
# sepal.length    5.80
# sepal.width     3.00
# petal.length    4.35
# petal.width     1.30
# dtype: float64
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
import seaborn as sns
import matplotlib as plt
df = pd.read_csv("data/iris.csv")

sns.set(style="whitegrid")
matplot = sns.pairplot(df, hue="variety", markers=["o", "s", "D"], diag_kind="hist")

# %%
from matplotlib import pyplot
df = pd.read_csv("data/iris.csv")
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
pyplot.figure(figsize=(12, 8))
sns.pairplot(df, hue='variety', palette='viridis')
pyplot.title('Pairwise Plot of the Iris Dataset')
pyplot.show()
